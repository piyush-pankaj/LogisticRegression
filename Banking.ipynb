# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/portu_banking_final.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   age          job  marital  ... euribor3m nr_employed  y
# 0  44  blue-collar  married  ...     4.963      5228.1  0
# 1  53   technician  married  ...     4.021      5195.8  0
# 2  28   management   single  ...     0.729      4991.6  1
# 3  39     services  married  ...     1.405      5099.1  0
# 4  55      retired  married  ...     0.869      5076.2  1
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  object
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  float64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp_var_rate    41188 non-null  float64
#  16  cons_price_idx  41188 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                   count         mean         std  ...       50%       75%       max
# duration        41188.0   258.285010  259.279249  ...   180.000   319.000  4918.000
# campaign        41188.0     2.567593    2.770014  ...     2.000     3.000    56.000
# pdays           41188.0   963.568005  211.772296  ...   999.000   999.000  9999.000
# previous        41188.0     0.172963    0.494901  ...     0.000     0.000     7.000
# emp_var_rate    41188.0     0.081886    1.570960  ...     1.100     1.400     1.400
# cons_price_idx  41188.0    93.575664    0.578840  ...    93.749    93.994    94.767
# cons_conf_idx   41188.0   -40.502600    4.628198  ...   -41.800   -36.400   -26.900
# euribor3m       41188.0     3.621291    1.734447  ...     4.857     4.961     5.045
# nr_employed     41188.0  5167.035911   72.251528  ...  5191.000  5228.100  5228.100
# y               41188.0     0.112654    0.316173  ...     0.000     0.000     1.000
#
# [10 rows x 8 columns]

# %%
df.y.value_counts()
# Out:
# 0    36548
# 1     4640
# Name: y, dtype: int64

# %%
df.job.unique()
# Out:
# array(['blue-collar', 'technician', 'management', 'services', 'retired',
#        'admin.', 'housemaid', 'unemployed', 'entrepreneur',
#        'self-employed', 'unknown', 'student', 'MANAGEMENT', 'RETIRED',
#        'STUDENT', 'ADMIN.', 'TECHNICIAN', 'BLUE-COLLAR', 'HOUSEMAID',
#        'SERVICES', 'UNKNOWN'], dtype=object)

# %%
df.groupby(["y"]).mean()
# Out:
#      duration  campaign       pdays  ...  cons_conf_idx  euribor3m  nr_employed
# y                                    ...
# 0  220.844807  2.633085  985.345135  ...     -40.593097   3.811491  5176.166600
# 1  553.191164  2.051724  792.035560  ...     -39.789784   2.123135  5095.115991
#
# [2 rows x 9 columns]

# %%
df.groupby(["job"]).mean()
# Out:
#                   duration  campaign  ...  nr_employed         y
# job                                   ...
# ADMIN.          637.000000  1.500000  ...  5191.000000  0.000000
# BLUE-COLLAR       5.000000  7.000000  ...  5099.100000  0.000000
# HOUSEMAID        84.000000  1.000000  ...  5195.800000  0.000000
# MANAGEMENT     1225.000000  2.000000  ...  5076.200000  0.000000
# RETIRED         545.000000  1.666667  ...  5087.866667  0.333333
# SERVICES        238.333333  2.000000  ...  5203.366667  0.000000
# STUDENT         638.500000  1.500000  ...  5000.150000  1.000000
# TECHNICIAN      834.000000  9.000000  ...  5191.000000  0.000000
# UNKNOWN          54.000000  4.000000  ...  5191.000000  0.000000
# admin.          254.238676  2.623704  ...  5164.120192  0.129750
# blue-collar     264.570410  2.557981  ...  5175.623419  0.068951
# entrepreneur    263.267857  2.535714  ...  5176.313530  0.085165
# housemaid       250.611898  2.641171  ...  5179.514259  0.100094
# ...

# %%
df.groupby(["marital"]).mean()
# Out:
#             duration  campaign       pdays  ...  euribor3m  nr_employed         y
# marital                                     ...
# D          87.500000  1.250000  999.000000  ...   4.909750  5209.550000  0.000000
# M         418.400000  2.600000  999.000000  ...   2.589200  5141.540000  0.000000
# S         283.333333  2.000000  999.000000  ...   3.531333  5152.733333  0.000000
# divorced  253.934679  2.614583  968.613498  ...   3.714567  5170.845074  0.103299
# married   257.406332  2.572804  967.963528  ...   3.746064  5171.854853  0.101593
# single    261.518720  2.533939  952.231474  ...   3.317391  5155.199905  0.140078
# unknown   312.725000  3.187500  937.100000  ...   3.313038  5157.393750  0.150000
#
# [7 rows x 10 columns]

# %%
df.groupby(["education"]).mean()
# Out:
#                        duration  campaign  ...  nr_employed         y
# education                                  ...
# basic-4y             259.750000  4.250000  ...  5167.266667  0.083333
# basic-6y             222.500000  2.500000  ...  5194.233333  0.000000
# basic-9y             144.900000  1.600000  ...  5161.490000  0.000000
# basic.4y             264.842459  2.595821  ...  5170.133117  0.102546
# basic.6y             264.524497  2.556430  ...  5174.666842  0.082240
# basic.9y             261.484673  2.533886  ...  5172.311914  0.078376
# high.school          260.886810  2.568576  ...  5164.994735  0.108355
# illiterate           276.777778  2.277778  ...  5171.777778  0.222222
# professional.course  252.533855  2.586115  ...  5170.155979  0.113485
# university.degree    253.223373  2.563527  ...  5163.226298  0.137245
# unknown              262.390526  2.596187  ...  5159.549509  0.145003
#
# [11 rows x 10 columns]

# %%
dff=['job','marital','education','default','loan','contact','month','day_of_week','poutcome']
for col in dff:
  plt.figure(figsize=(5,5))
  sns.barplot(df[col].value_counts().values,df[col].value_counts().index)
  plt.title(col)
plt.show()

# %%
plt.hist(df['age'])
# Out:
# (array([1.6660e+03, 1.1344e+04, 1.2036e+04, 8.0880e+03, 5.8220e+03,
#         1.6130e+03, 3.1800e+02, 2.0200e+02, 8.9000e+01, 1.0000e+01]),
#  array([17. , 25.1, 33.2, 41.3, 49.4, 57.5, 65.6, 73.7, 81.8, 89.9, 98. ]),
#  <a list of 10 Patch objects>)

# %%
df['job']=df['job'].replace({'blue-collar':'BLUE-COLLAR','technician':'TECHNICIAN','management':'MANAGEMENT',\
                   'services':'SERVICES','retired':'RETIRED','admin.':'ADMIN','ADMIN.':'ADMIN','housemaid':'HOUSEMAID',\
                   'unemployed':'UNEMPLOYED','entrepreneur':'ENTREPRENEUR','self-employed':'SELF-EMPLOYED',\
                   'unknown':'ADMIN','UNKNOWN':'ADMIN','student':'STUDENT'})

# %%
df.job.unique()
# Out:
# array(['BLUE-COLLAR', 'TECHNICIAN', 'MANAGEMENT', 'SERVICES', 'RETIRED',
#        'ADMIN', 'HOUSEMAID', 'UNEMPLOYED', 'ENTREPRENEUR',
#        'SELF-EMPLOYED', 'STUDENT'], dtype=object)

# %%
df.job.value_counts()
# Out:
# ADMIN            10752
# BLUE-COLLAR       9254
# TECHNICIAN        6743
# SERVICES          3969
# MANAGEMENT        2924
# RETIRED           1720
# ENTREPRENEUR      1456
# SELF-EMPLOYED     1421
# HOUSEMAID         1060
# UNEMPLOYED        1014
# STUDENT            875
# Name: job, dtype: int64

# %%
obj_cols = df.select_dtypes(include='object')
obj_cols
# Out:
#       age          job  marital  ... month day_of_week     poutcome
# 0      44  BLUE-COLLAR  married  ...   aug         thu  nonexistent
# 1      53   TECHNICIAN  married  ...   nov         fri  nonexistent
# 2      28   MANAGEMENT   single  ...   jun         thu      success
# 3      39     SERVICES  married  ...   apr         fri  nonexistent
# 4      55      RETIRED  married  ...   aug         fri      success
# ...    ..          ...      ...  ...   ...         ...          ...
# 41183  59      RETIRED  married  ...   jun         thu  nonexistent
# 41184  31    HOUSEMAID  married  ...   may         thu  nonexistent
# 41185  42        ADMIN   single  ...   may         wed  nonexistent
# 41186  48   TECHNICIAN  married  ...   oct         tue  nonexistent
# 41187  25      STUDENT   single  ...   may         fri  nonexistent
#
# [41188 rows x 11 columns]

# %%
df.age.unique()
# Out:
# array(['44', '53', '28', '39', '55', '30', '37', '36', '27', '34', '41',
#        '33', '26', '52', '35', '40', '32', '49', '38', '47', '46', '29',
#        '54', '42', '72', '48', '43', '56', '31', '24', '68', '59', '50',
#        '45', '35-30', '25', '57', '63', '58', '60', '30-35', '64', '51',
#        '23', '20', '74', '80', '61', '25-30', '62', '75', '21', '82',
#        '77', '18-25', '30-32', '70', '50-55', '76', '73', '66', '22',
#        '71', '19', '79', '88', '65', '67', '81', '18', '84', '69', '98',
#        '85', '83', '78', '92', '45-50', '20-25', '20-40', '35-40', '86',
#        '94', '17', '91', '89', '87', '95', '30-40', 56, 39, 30, 53, 37,
#        22, 45, 31, 24, 50, 58, 33, 27, 28, 32, 51, 41, 49, 43, 44, 35, 29,
#        26, 57, 25, 42, 48, 46, 67, 38, 34, 54, 40, 23, 47, 62, 75, 55, 36,
#        52, 59, 78, 70, 60, 20, 66, 61, 21, 88, 18, 68, 71, 73, 80, 79, 63,
#        76, 83, 65, 19, 86, 17, 72, 69, 81, 64, 77, 74, 85, 82],
#       dtype=object)

# %%
df['age'] = df['age'].replace({'35-30':'33','30-35':'33','25-30':'28','18-25':'22','30-32':'31','50-55':'53','45-50':'48','20-25':'23','20-40':'30','35-40':'38','30-40':'35'})

# %%
df.age.unique()
# Out:
# array(['44', '53', '28', '39', '55', '30', '37', '36', '27', '34', '41',
#        '33', '26', '52', '35', '40', '32', '49', '38', '47', '46', '29',
#        '54', '42', '72', '48', '43', '56', '31', '24', '68', '59', '50',
#        '45', '25', '57', '63', '58', '60', '64', '51', '23', '20', '74',
#        '80', '61', '62', '75', '21', '82', '77', '22', '70', '76', '73',
#        '66', '71', '19', '79', '88', '65', '67', '81', '18', '84', '69',
#        '98', '85', '83', '78', '92', '86', '94', '17', '91', '89', '87',
#        '95', 56, 39, 30, 53, 37, 22, 45, 31, 24, 50, 58, 33, 27, 28, 32,
#        51, 41, 49, 43, 44, 35, 29, 26, 57, 25, 42, 48, 46, 67, 38, 34, 54,
#        40, 23, 47, 62, 75, 55, 36, 52, 59, 78, 70, 60, 20, 66, 61, 21, 88,
#        18, 68, 71, 73, 80, 79, 63, 76, 83, 65, 19, 86, 17, 72, 69, 81, 64,
#        77, 74, 85, 82], dtype=object)

# %%
df['age'] = df['age'].astype('int64')

# %%
cols = list(obj_cols)
i = 0
for col in obj_cols:
  print(cols[i],obj_cols[col].unique())
  i += 1
# Out:
# age ['44' '53' '28' '39' '55' '30' '37' '36' '27' '34' '41' '33' '26' '52'
#  '35' '40' '32' '49' '38' '47' '46' '29' '54' '42' '72' '48' '43' '56'
#  '31' '24' '68' '59' '50' '45' '35-30' '25' '57' '63' '58' '60' '30-35'
#  '64' '51' '23' '20' '74' '80' '61' '25-30' '62' '75' '21' '82' '77'
#  '18-25' '30-32' '70' '50-55' '76' '73' '66' '22' '71' '19' '79' '88' '65'
#  '67' '81' '18' '84' '69' '98' '85' '83' '78' '92' '45-50' '20-25' '20-40'
#  '35-40' '86' '94' '17' '91' '89' '87' '95' '30-40' 56 39 30 53 37 22 45
#  31 24 50 58 33 27 28 32 51 41 49 43 44 35 29 26 57 25 42 48 46 67 38 34
#  54 40 23 47 62 75 55 36 52 59 78 70 60 20 66 61 21 88 18 68 71 73 80 79
#  63 76 83 65 19 86 17 72 69 81 64 77 74 85 82]
# job ['BLUE-COLLAR' 'TECHNICIAN' 'MANAGEMENT' 'SERVICES' 'RETIRED' 'ADMIN'
#  'HOUSEMAID' 'UNEMPLOYED' 'ENTREPRENEUR' 'SELF-EMPLOYED' 'STUDENT']
# marital ['married' 'single' 'divorced' 'D' 'unknown' 'S' 'M']
# ...

# %%
df.marital.value_counts()
# Out:
# married     24923
# single      11565
# divorced     4608
# unknown        80
# M               5
# D               4
# S               3
# Name: marital, dtype: int64

# %%
df['marital'] = df['marital'].replace({'M':'married','unknown':'married','D':'divorced','S':'single'})

# %%
df.marital.value_counts()
# Out:
# married     25008
# single      11568
# divorced     4612
# Name: marital, dtype: int64

# %%
df.education.value_counts()
# Out:
# university.degree      12168
# high.school             9515
# basic.9y                6035
# professional.course     5243
# basic.4y                4164
# basic.6y                2286
# unknown                 1731
# illiterate                18
# basic-4y                  12
# basic-9y                  10
# basic-6y                   6
# Name: education, dtype: int64

# %%
df['education'] = df['education'].replace({'basic-4y':'basic.4y', 'unknown' :'university.degree', 'basic-9y':'basic.9y','basic-6y':'basic.6y'})

# %%
df.education.value_counts()
# Out:
# university.degree      13899
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# illiterate                18
# Name: education, dtype: int64

# %%
df.default.value_counts()
# Out:
# no         32588
# unknown     8597
# yes            3
# Name: default, dtype: int64

# %%
df['default'] = df['default'].replace({'unknown':'no'})

# %%
df.housing.value_counts()
# Out:
# yes        21576
# no         18622
# unknown      990
# Name: housing, dtype: int64

# %%
df['housing'] = df['housing'].replace({'unknown':'yes'})

# %%
df.loan.value_counts()
# Out:
# no         33950
# yes         6248
# unknown      990
# Name: loan, dtype: int64

# %%
df['loan'] = df['loan'].replace({'unknown':'no'})

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
obj_cols.drop(['age','month','day_of_week'],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
obj_cols.columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'poutcome'],
#       dtype='object')

# %%
df1=df
for m in obj_cols:
  dummies =pd.get_dummies(df[m],drop_first=True)
  df1 = pd.concat([df1,dummies],axis='columns')

# %%
df1.head()
# Out:
#    age          job  marital  ... telephone nonexistent success
# 0   44  BLUE-COLLAR  married  ...         0           1       0
# 1   53   TECHNICIAN  married  ...         0           1       0
# 2   28   MANAGEMENT   single  ...         0           0       1
# 3   39     SERVICES  married  ...         0           1       0
# 4   55      RETIRED  married  ...         0           0       1
#
# [5 rows x 45 columns]

# %%
df1.drop(['job','marital','education','default','housing','loan','contact','day_of_week','month','poutcome'],axis=1,inplace=True)

# %%
df1['target'] = df['y']

# %%
df1.head()
# Out:
#    age  duration  campaign  pdays  ...  telephone  nonexistent  success  target
# 0   44       210         1  999.0  ...          0            1        0       0
# 1   53       138         1  999.0  ...          0            1        0       0
# 2   28       339         3    6.0  ...          0            0        1       1
# 3   39       185         2  999.0  ...          0            1        0       0
# 4   55       137         1    3.0  ...          0            0        1       1
#
# [5 rows x 36 columns]

# %%
df1.drop(['y'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#    age  duration  campaign  pdays  ...  telephone  nonexistent  success  target
# 0   44       210         1  999.0  ...          0            1        0       0
# 1   53       138         1  999.0  ...          0            1        0       0
# 2   28       339         3    6.0  ...          0            0        1       1
# 3   39       185         2  999.0  ...          0            1        0       0
# 4   55       137         1    3.0  ...          0            0        1       1
#
# [5 rows x 35 columns]

# %%
X = df1.iloc[:,:-1]
display(X)
y = df1.iloc[:,-1]
display(y)
# Out:
#        age  duration  campaign  pdays  ...  yes  telephone  nonexistent  success
# 0       44       210         1  999.0  ...    0          0            1        0
# 1       53       138         1  999.0  ...    0          0            1        0
# 2       28       339         3    6.0  ...    0          0            0        1
# 3       39       185         2  999.0  ...    0          0            1        0
# 4       55       137         1    3.0  ...    0          0            0        1
# ...    ...       ...       ...    ...  ...  ...        ...          ...      ...
# 41183   59       222         1  999.0  ...    1          1            1        0
# 41184   31       196         2  999.0  ...    0          1            1        0
# 41185   42        62         3  999.0  ...    1          1            1        0
# 41186   48       200         2  999.0  ...    1          1            1        0
# 41187   25       112         4  999.0  ...    0          1            1        0
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state= 42)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.9103946133177948

# %%
lr.score(X_test,y_test)
# Out:
# 0.904243954549869

# %%
pred = lr.predict(X_test)
pred
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      9111
#            1       0.63      0.40      0.49      1186
#
#     accuracy                           0.90     10297
#    macro avg       0.78      0.69      0.72     10297
# weighted avg       0.89      0.90      0.89     10297

# %%
print(accuracy_score(y_test,pred)*100)
# Out:
# 90.4243954549869

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,pred))
# Out:
# [[8836  275]
#  [ 711  475]]

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0)))

# import SMOTE module from imblearn library
# pip install imblearn (if you don't have imblearn in your system)
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
X_train_smote, y_train_smote = sm.fit_resample(X_train.values, y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(X_train_smote.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_smote.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_smote == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_smote == 0)))
# Out:
# Before OverSampling, counts of label '1': 3454
# Before OverSampling, counts of label '0': 27437
#
# After OverSampling, the shape of train_X: (54874, 34)
# After OverSampling, the shape of train_y: (54874,)
#
# After OverSampling, counts of label '1': 27437
# After OverSampling, counts of label '0': 27437

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_smote,y_train_smote,test_size = 0.25,random_state = 42)

# %%
lr.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
lr.score(X_test,y_test)
# Out:
# 0.8569866608353378

# %%
preds = lr.predict(X_test)
preds
# Out:
# array([1, 0, 1, ..., 0, 1, 1])

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86      6822
#            1       0.86      0.86      0.86      6897
#
#     accuracy                           0.86     13719
#    macro avg       0.86      0.86      0.86     13719
# weighted avg       0.86      0.86      0.86     13719

# %%
print(accuracy_score(y_test,preds)*100)
# Out:
# 85.69866608353378

# %%
print(confusion_matrix(y_test,preds))
# Out:
# [[5832  990]
#  [ 972 5925]]

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.feature_selection import RFE


rfe = RFE(lr, n_features_to_select= None)
rfe = rfe.fit(X_train, y_train)


print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False False  True False  True False False  True  True False  True False
#  False  True  True False  True  True  True False False  True False  True
#  False False False  True False  True  True  True False  True]
# [13 12  1 16  1  4  2  1  1  6  1  7 14  1  1 11  1  1  1 10  3  1  9  1
#   5 17  8  1 18  1  1  1 15  1]
